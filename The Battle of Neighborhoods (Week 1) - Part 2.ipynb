# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 1) - Part 2

# %% [markdown]
# ### Data 1

# %% [markdown]
# According to https://en.wikipedia.org/wiki/Riyadh, the city of Riyadh has about 130 total districts or neghborhoods. Riyadh has a population of 7.6 million people and receives around 5 million tourists each year.
#
# We will be using the information provided in this Wiki page to navigate any information needed to know about the city.

# %% [markdown]
# ### Data 2

# %% [markdown]
# We'll be needing Foursquare's API to navigate the city's geographical coordinates data. We have created a developer accound and have a Client Id & Secret that would be needed when quering for data. We're going to explore and target recommended locations across different district to determine which location would suffice as a starting point for the first branch. Clustering, visualization and data cleaning will be done during this assignment to reach a suitable answer of our problem.
